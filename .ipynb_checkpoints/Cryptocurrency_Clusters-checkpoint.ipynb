# %%
# Dependancies set up
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans

# %%
# Loading the CSV file into the dataframe
crypto_df = pd.read_csv('Instructions/crypto_data.csv')
crypto_df.head(15)
# Out:
#    Unnamed: 0          CoinName       Algorithm  IsTrading ProofType  \
# 0          42           42 Coin          Scrypt       True   PoW/PoS
# 1         365           365Coin             X11       True   PoW/PoS
# 2         404           404Coin          Scrypt       True   PoW/PoS
# 3         611         SixEleven         SHA-256       True       PoW
# 4         808               808         SHA-256       True   PoW/PoS
# 5        1337         EliteCoin             X13       True   PoW/PoS
# 6        2015         2015 coin             X11       True   PoW/PoS
# 7         BTC           Bitcoin         SHA-256       True       PoW
# 8         ETH          Ethereum          Ethash       True       PoW
# 9         LTC          Litecoin          Scrypt       True       PoW
# 10       DASH              Dash             X11       True   PoW/PoS
# 11        XMR            Monero  CryptoNight-V7       True       PoW
# 12        ETC  Ethereum Classic          Ethash       True       PoW
# 13        ZEC             ZCash        Equihash       True       PoW
# 14        BTS         Bitshares         SHA-512       True       PoS
#
#     TotalCoinsMined TotalCoinSupply
# 0      4.199995e+01              42
# 1               NaN      2300000000
# 2      1.055185e+09       532000000
# 3               NaN          611000
# 4      0.000000e+00               0
# 5      2.927942e+10    314159265359
# 6               NaN               0
# 7      1.792718e+07        21000000
# 8      1.076842e+08               0
# 9      6.303924e+07        84000000
# 10     9.031294e+06        22000000
# 11     1.720114e+07               0
# 12     1.133597e+08       210000000
# 13     7.383056e+06        21000000
# 14     2.741570e+09      3600570502

# %%
# Filtering for currencies that are still being traded
current_crypto_df = crypto_df[crypto_df['IsTrading'] == True]
current_crypto_df.head()
# Out:
#   Unnamed: 0   CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42    42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 1        365    365Coin       X11       True   PoW/PoS              NaN
# 2        404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 3        611  SixEleven   SHA-256       True       PoW              NaN
# 4        808        808   SHA-256       True   PoW/PoS     0.000000e+00
#
#   TotalCoinSupply
# 0              42
# 1      2300000000
# 2       532000000
# 3          611000
# 4               0

# %%
# Drop 'IsTrading' Column
crypto_df = crypto_df.drop(columns ='IsTrading')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/4x/fb2zx6qs6g1br4cht977pqsr0000gn/T/ipykernel_33459/2415178031.py in <module>
#       1 # Drop 'IsTrading' Column
# ----> 2 crypto_df = crypto_df.drop(columns ='IsTrading')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['IsTrading'] not found in axis"

# %%
# Check for null values
crypto_df.isnull().sum()
# Out:
# Unnamed: 0           0
# CoinName             0
# Algorithm            0
# ProofType            0
# TotalCoinsMined    508
# TotalCoinSupply      0
# dtype: int64

# %%
# Removing all rows with null values
crypto_df = crypto_df.dropna()

# %%
# Verifying that the null valued rows are dropped
crypto_df.isnull().sum()
# Out:
# Unnamed: 0         0
# CoinName           0
# Algorithm          0
# ProofType          0
# TotalCoinsMined    0
# TotalCoinSupply    0
# dtype: int64

# %%
# Filtering for the crpytocurrencies that have been mined already
mined_crypto_df = crypto_df[crypto_df["TotalCoinsMined"]> 0]
mined_crypto_df.head()
# Out:
#   Unnamed: 0 Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42    Scrypt   PoW/PoS     4.199995e+01              42
# 2        404    Scrypt   PoW/PoS     1.055185e+09       532000000
# 5       1337       X13   PoW/PoS     2.927942e+10    314159265359
# 7        BTC   SHA-256       PoW     1.792718e+07        21000000
# 8        ETH    Ethash       PoW     1.076842e+08               0

# %%
# Saving the 'CoinName' column for t-SNE
CoinName=pd.DataFrame(crypto_df['CoinName']).reset_index(drop=True)
CoinName
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CoinName'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/4x/fb2zx6qs6g1br4cht977pqsr0000gn/T/ipykernel_33459/952153895.py in <module>
#       1 # Saving the 'CoinName' column for t-SNE
# ----> 2 CoinName=pd.DataFrame(crypto_df['CoinName']).reset_index(drop=True)
#       3 CoinName
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'CoinName'

# %%
# Dropping the 'CoinName' column from the dataframe considering it has no value in the contribution to the data that we seek
mined_crypto_df.drop(columns='CoinName', axis=1, inplace= True)
mined_crypto_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/4x/fb2zx6qs6g1br4cht977pqsr0000gn/T/ipykernel_33459/3626340906.py in <module>
#       1 # Dropping the 'CoinName' column from the dataframe considering it has no value in the contribution to the data that we seek
# ----> 2 mined_crypto_df.drop(columns='CoinName', axis=1, inplace= True)
#       3 mined_crypto_df
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['CoinName'] not found in axis"

# %%
# Dropping 'Unnamed' column
crypto_df = crypto_df.drop(columns=['Unnamed: 0'])
crypto_df
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0          Scrypt   PoW/PoS     4.199995e+01              42
# 2          Scrypt   PoW/PoS     1.055185e+09       532000000
# 4         SHA-256   PoW/PoS     0.000000e+00               0
# 5             X13   PoW/PoS     2.927942e+10    314159265359
# 7         SHA-256       PoW     1.792718e+07        21000000
# ...           ...       ...              ...             ...
# 1242       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245  CryptoNight       PoW     9.802226e+08      1400222610
# 1246     Equihash       PoW     7.296538e+06        21000000
# 1247       Scrypt       PoS     1.283270e+05         1000000
# 1248       Scrypt   PoW/PoS     2.149121e+07       100000000
#
# [744 rows x 4 columns]

# %%
# Converting the algorithm and prooftype into numerical data
X = pd.get_dummies(crypto_df, columns=['Algorithm', 'ProofType'])
X
# Out:
#       TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 0        4.199995e+01              42                                 0
# 2        1.055185e+09       532000000                                 0
# 4        0.000000e+00               0                                 0
# 5        2.927942e+10    314159265359                                 0
# 7        1.792718e+07        21000000                                 0
# ...               ...             ...                               ...
# 1242     1.493105e+07       250000000                                 0
# 1245     9.802226e+08      1400222610                                 0
# 1246     7.296538e+06        21000000                                 0
# 1247     1.283270e+05         1000000                                 0
# 1248     2.149121e+07       100000000                                 0
#
#       Algorithm_536  Algorithm_Argon2  Algorithm_Argon2d  Algorithm_BLAKE256  \
# 0                 0                 0                  0                   0
# 2                 0                 0                  0                   0
# 4                 0                 0                  0                   0
# 5                 0                 0                  0                   0
# 7                 0                 0                  0                   0
# ...             ...               ...                ...                 ...
# 1242              0                 0                  0                   0
# 1245              0                 0                  0                   0
# 1246              0                 0                  0                   0
# 1247              0                 0                  0                   0
# 1248              0                 0                  0                   0
#
#       Algorithm_Blake  Algorithm_Blake2S  Algorithm_Blake2b  ...  \
# 0                   0                  0                  0  ...
# 2                   0                  0                  0  ...
# 4                   0                  0                  0  ...
# 5                   0                  0                  0  ...
# 7                   0                  0                  0  ...
# ...               ...                ...                ...  ...
# 1242                0                  0                  0  ...
# 1245                0                  0                  0  ...
# 1246                0                  0                  0  ...
# 1247                0                  0                  0  ...
# 1248                0                  0                  0  ...
#
#       ProofType_PoW/PoS  ProofType_PoW/PoS   ProofType_PoW/PoW  \
# 0                     1                   0                  0
# 2                     1                   0                  0
# 4                     1                   0                  0
# 5                     1                   0                  0
# 7                     0                   0                  0
# ...                 ...                 ...                ...
# 1242                  1                   0                  0
# 1245                  0                   0                  0
# 1246                  0                   0                  0
# 1247                  0                   0                  0
# 1248                  1                   0                  0
#
#       ProofType_PoW/nPoS  ProofType_Pos  ProofType_Proof of Authority  \
# 0                      0              0                             0
# 2                      0              0                             0
# 4                      0              0                             0
# 5                      0              0                             0
# 7                      0              0                             0
# ...                  ...            ...                           ...
# 1242                   0              0                             0
# 1245                   0              0                             0
# 1246                   0              0                             0
# 1247                   0              0                             0
# 1248                   0              0                             0
#
#       ProofType_Proof of Trust  ProofType_TPoS  \
# 0                            0               0
# 2                            0               0
# 4                            0               0
# 5                            0               0
# 7                            0               0
# ...                        ...             ...
# 1242                         0               0
# 1245                         0               0
# 1246                         0               0
# 1247                         0               0
# 1248                         0               0
#
#       ProofType_Zero-Knowledge Proof  ProofType_dPoW/PoW
# 0                                  0                   0
# 2                                  0                   0
# 4                                  0                   0
# 5                                  0                   0
# 7                                  0                   0
# ...                              ...                 ...
# 1242                               0                   0
# 1245                               0                   0
# 1246                               0                   0
# 1247                               0                   0
# 1248                               0                   0
#
# [744 rows x 113 columns]

# %%
# Standarize the dataset
scaler = StandardScaler()
crypto_scaled = scaler.fit_transform(X)

# %%
# Number of features in cleaned dataset
len(X.columns)
# Out:
# 113

# %%
# Reducing dimensions from 113 to 4 using PCA
pca = PCA(n_components=4)

# Grabbing three principal components for the crypto data.
crypto_pca1 = pca.fit_transform(crypto_scaled)

# %%
# Creating a dataframe from the PCA data
crypto_pca1_df = pd.DataFrame(data=crypto_pca1, 
                             columns=["PC 1", "PC 2", "PC 3", "PC4"])
crypto_pca1_df.head()
# Out:
#        PC 1      PC 2      PC 3       PC4
# 0 -0.226067  1.265476 -0.355333  0.002564
# 1 -0.210653  1.264513 -0.355706  0.002630
# 2 -0.164410  0.790963 -0.187927  0.005151
# 3  0.345999  1.973607 -0.377608 -0.009824
# 4 -0.197558 -1.497198  0.110393  0.003903

# %%
# Viewing the explained variance ratio
pca.explained_variance_ratio_
# Out:
# array([0.01968821, 0.01853682, 0.0177504 , 0.01772103])

# %%
# Using PCA we preserve 90% of the 'explained variance' through dimension reduction
pca_2 = PCA(n_components=.90)

# Grabbing three principal components for the crypto data.
crypto_pca = pca_2.fit_transform(crypto_scaled)
crypto_pca
# Out:
# array([[-2.21380021e-01,  1.29786142e+00, -4.57924159e-01, ...,
#         -1.98863372e-13, -1.97439802e-13, -1.14858610e-12],
#        [-2.06313067e-01,  1.29666010e+00, -4.58523177e-01, ...,
#         -1.99534225e-13, -1.97264262e-13, -1.14877757e-12],
#        [-1.55752643e-01,  8.27385859e-01, -2.81079456e-01, ...,
#          3.86123323e-15, -1.04765596e-14,  3.64111920e-15],
#        ...,
#        [-2.54104120e-01, -2.04610437e+00,  2.31880763e-01, ...,
#         -2.01055603e-13, -1.98413438e-13, -1.15476455e-12],
#        [-9.35278442e-02,  7.77886967e-01, -1.96852306e-01, ...,
#         -2.02000130e-13, -1.92758351e-13, -1.15228388e-12],
#        [-2.21073149e-01,  1.29783695e+00, -4.57936360e-01, ...,
#         -1.99674642e-13, -1.97396836e-13, -1.14871586e-12]])

# %%
# Creating a dataframe from the PCA data
pca_data_df = pd.DataFrame(data=crypto_pca)
pca_data_df.head()
# Out:
#          0         1         2             3             4             5   \
# 0 -0.221380  1.297861 -0.457924 -3.000308e-07 -4.696449e-12 -1.026088e-10
# 1 -0.206313  1.296660 -0.458523 -3.000308e-07 -4.696780e-12 -1.026088e-10
# 2 -0.155753  0.827386 -0.281079 -2.148769e-07 -3.362625e-12 -7.348888e-11
# 3  0.295682  1.990917 -0.487168 -4.308326e-07 -6.735908e-12 -1.473513e-10
# 4 -0.189728 -1.486730  0.110284  1.780704e-07  2.784252e-12  6.090726e-11
#
#              6             7         8         9   ...            78  \
# 0 -9.469125e-11 -2.624791e-10  0.010056 -1.052602  ...  3.969199e-13
# 1 -9.469112e-11 -2.624788e-10  0.008591 -1.055935  ...  3.970771e-13
# 2 -6.781651e-11 -1.879848e-10 -0.003988 -0.662536  ... -1.480926e-14
# 3 -1.359724e-10 -3.769115e-10 -0.037589 -0.805303  ... -6.087631e-14
# 4  5.620112e-11  1.557945e-10 -0.001555 -0.032531  ... -1.908184e-14
#
#              79            80            81            82            83  \
# 0 -1.642885e-13 -2.150222e-14  2.007854e-13 -1.089232e-12  4.445127e-14
# 1 -1.638803e-13 -2.160269e-14  2.013983e-13 -1.088697e-12  4.401789e-14
# 2  9.591018e-15 -1.703846e-14 -5.591316e-15 -6.881815e-15 -1.525208e-14
# 3  3.464272e-14 -2.169509e-14 -3.404832e-14 -9.042108e-14 -3.478408e-14
# 4  1.333226e-14 -1.289658e-14 -7.886441e-15 -8.339324e-15 -1.387194e-14
#
#              84            85            86            87
# 0  7.779639e-13 -1.988634e-13 -1.974398e-13 -1.148586e-12
# 1  7.780471e-13 -1.995342e-13 -1.972643e-13 -1.148778e-12
# 2 -1.956447e-14  3.861233e-15 -1.047656e-14  3.641119e-15
# 3  4.053845e-15 -3.808218e-14 -1.264374e-14 -6.399709e-14
# 4 -1.500852e-14 -9.751885e-17 -1.038284e-14  4.863485e-16
#
# [5 rows x 88 columns]

# %%
# Fetching the explained variance
pca.explained_variance_ratio_
# Out:
# array([0.01968821, 0.01853682, 0.0177504 , 0.01772103])

# %%
# Creating a bar chart with explained variance
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_ratio_, color='blue')
plt.xlabel('PCA features')
plt.ylabel('Variance %')
plt.xticks(features)
# Out:
# ([<matplotlib.axis.XTick at 0x7f96c0203280>,
#   <matplotlib.axis.XTick at 0x7f96c0203250>,
#   <matplotlib.axis.XTick at 0x7f96c01dfdc0>,
#   <matplotlib.axis.XTick at 0x7f96d0a50130>],
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %%
# The number of features shows 90% of original dataset with 88
len(pca_data_df.columns)
# Out:
# 88

# %%
# Priming the t-SNE model
t_sne = TSNE(learning_rate=35)

# %%
# Reducing the dimensions down to two using the t-SNE model
t_sne_features = t_sne.fit_transform(pca_data_df)
t_sne_features.shape
# Out:
# (744, 2)
